# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %% [markdown]
# #Assignment 3
# ###Mathematical Applications in Computer Science
#
# ###This is the work of:
# Student1_name (Student1_ID)<br>
# Student2_name (Student2_ID)

# %% [markdown]
# ###Exercise 1:

# %% [markdown]
# #####(a) Complete the following function:

# %%
# 1(a)
def lemniscate(f,d):
  pass

# %% [markdown]
# #####(b) Draw the lemniscate for f=5

# %%
# 1(b)

# %% [markdown]
# #####(c) Is there a problem with the graph above? If so, what is it? What made this problem? How can we fix/minimize this error? (english)

# %% [markdown]
# 1(c) *Replace this with your answer to 1(c)*

# %% [markdown]
# #####(d) Draw another example or 2 which show how your solution is beneficial.

# %%
# 1(d)

# %% [markdown]
# ###Exercise 2:

# %% [markdown]
# #####(a) Complete the following function:

# %%
# 2(a)
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

def torus(r, R):
    num_points=100
    theta = np.linspace(0, 2 * np.pi, num_points)
    phi = np.linspace(0, 2 * np.pi, num_points)
    theta, phi = np.meshgrid(theta, phi)

    x = (R + r * np.cos(theta)) * np.cos(phi)
    y = (R + r * np.cos(theta)) * np.sin(phi)
    z = r * np.sin(theta)

    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')
    ax.plot_surface(x, y, z, alpha=0.8, edgecolor='k')
    ax.set_title(f'Torus with R={R}, r={r}')
    plt.show()

# %% [markdown]
# #####(b) Draw a torus with r=R=1

# %%
# 2(b)
torus(1, 1)

# %% [markdown]
# #####(c) Increase the values of r and R (separately). What is the meaning of each of these parameters and how can it be seen in the torus' shape? Draw examples that support your claim.

# %% [markdown]
# - Increasing `r` makes the "tube" of the torus thicker.
# - Increasing `R` makes the whole torus larger in radius (the hole in the middle gets wider).
# - When both `r` and `R` are increased, the torus becomes larger and fatter.

# %%
# 2(c) - code for making the examples:
torus(2, 1)

torus(1, 2)

torus(2, 2)

# %% [markdown]
# 2(c) *Replace this with your verbal answer to 2(c)*
